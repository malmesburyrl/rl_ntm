# %%
#IPython magic to reload libraries
# %load_ext autoreload
# %autoreload 2

# Extra code so Juypter doesn't crash on mac os
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import sys
sys.path.insert(0, 'utils')  # noqa

import numpy as np
import gym
import tasks
import ntm
import interfaces

# %%
# Training Params
train_iter = 1000
batch_size = 1

# %%
# Task
string_len=5
num_char = 5
env = tasks.Copy(string_len=string_len, max_char=num_char)

# %%
# Controller 
Controller = ntm.NTM(memory_vector_len=10, num_char=num_char, max_run_time=20)

# %%
# #Over Fit on single char
# output = Controller.run(tape_input=1, writes_left=1)
# print(output)
# Controller.update(output_target=4)

# %%
# # Test RL training
# output = Controller.run(tape_input=1, writes_left=1)
# print(Controller.run_time)
# print(Controller.run_time_left(1))
# Controller.update_store(1, done=True)

# %%
# print(Controller.run_time)

# %%
output_control_cmds = ["no","yes"]
input_control_cmds = {-1:"left",0:"stay",1:"right"}
# input_control_cmds = ["left","stay","right"]
int_to_char = ["A","B","C","D","E","F","G"]
render_env = False
for i in range(train_iter):
# for i in range(1):

    # Collect experince using current policy/controller
    for j in range(batch_size):
        
        episode_steps = 0
        observation, target, done, info = env.reset()
        if render_env: env.render()

        while True:
            episode_steps += 1
            
            #Run RL-NTM controller and get outputs
            outputs = Controller.run(tape_input=observation, writes_left=info)

            output_content = outputs[0] # Which character to write (ignored if the above sub-action is 0) 
            output_control = outputs[1] #  Whether to write to the output tape ["no","yes"] = [0,1]
            input_control = outputs[2] # Direction to move the read head ["left","right"] = [0,1]
           
            actions = (input_control, output_control, output_content)
            
            if render_env:
                print("Policy - obs: {} action: {}, {}, {}".format(int_to_char[observation],
                      int_to_char[output_content],
                      output_control_cmds[output_control],
                      input_control_cmds[input_control]))

            # target is the expected output for the action that was just taken
            observation, target, done, info = env.step(actions)
            if render_env: env.render()
                
            if output_control_cmds[output_control] == "yes":
                Controller.update_store(output_target=target, done=done)
                
            if done:
                done = False
                break
# Out:
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.7249497
# 3 -1.7962592
# 2 -2.1880238
# 1 -1.7249497
# 0 -1.5427974
# Objective Function J(0):  -8.97697925567627
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.3888799
# 3 -1.5570896
# 2 -1.7467765
# 1 -1.4181633
# 0 -1.982384
# Objective Function J(0):  -8.093293190002441
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.4348782
# 3 -1.4288241
# 2 -1.4348782
# 1 -1.8219099
# 0 -1.6560596
# Objective Function J(0):  -7.77655029296875
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.548211
# 3 -1.7404819
# 2 -1.7404819
# 1 -1.7404819
# 0 -1.7404819
# Objective Function J(0):  -8.510138511657715
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.96083575
# 3 -1.2421161
# 2 -1.6521038
# 1 -0.96083575
# 0 -1.6521038
# Objective Function J(0):  -6.467995643615723
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.9241812
# 3 -1.9562865
# 2 -1.9562865
# 1 -1.078782
# 0 -1.078782
# Objective Function J(0):  -6.99431848526001
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.653968
# 3 -2.418387
# 2 -0.71404845
# 1 -2.418387
# 0 -0.9762314
# Objective Function J(0):  -8.181021690368652
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.9283424
# 3 -0.9283424
# 2 -1.1423202
# 1 -1.6005728
# 0 -0.9283424
# Objective Function J(0):  -5.527920246124268
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.7223988
# 3 -0.92130405
# 2 -1.6958213
# 1 -0.92130405
# 0 -1.6958213
# Objective Function J(0):  -5.9566497802734375
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -2.1177478
# 3 -0.60397434
# 2 -0.60397434
# 1 -0.80376065
# 0 -0.80376065
# Objective Function J(0):  -4.933217525482178
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.8192807
# 3 -2.7067971
# 2 -0.70577633
# 1 -1.8192807
# 0 -0.40814182
# Objective Function J(0):  -7.45927619934082
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.720265
# 3 -0.83797836
# 2 -2.0149019
# 1 -2.0496523
# 0 -0.720265
# Objective Function J(0):  -6.343062400817871
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.8536895
# 3 -0.8536895
# 2 -1.5194638
# 1 -0.6520816
# 0 -1.5194638
# Objective Function J(0):  -5.398387908935547
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.53688306
# 3 -1.3792444
# 2 -2.0809007
# 1 -0.7189143
# 0 -1.3792444
# Objective Function J(0):  -6.095186710357666
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.1003003
# 3 -0.73128504
# 2 -0.75882894
# 1 -0.75882894
# 0 -1.9005032
# Objective Function J(0):  -5.249746322631836
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.8872145
# 3 -1.8872145
# 2 -2.506914
# 1 -1.8872145
# 0 -0.6453202
# Objective Function J(0):  -8.81387710571289
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.3898954
# 3 -1.9683516
# 2 -1.1732867
# 1 -1.3898954
# 0 -1.3898954
# Objective Function J(0):  -7.311324596405029
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.74681
# 3 -1.616948
# 2 -1.616948
# 1 -1.74681
# 0 -1.74681
# Objective Function J(0):  -8.474326133728027
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.2415189
# 3 -1.4400214
# 2 -1.4400214
# 1 -0.89695346
# 0 -1.4400214
# Objective Function J(0):  -6.458536624908447
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.1935992
# 3 -0.976629
# 2 -1.1935992
# 1 -1.1389258
# 0 -1.1389258
# Objective Function J(0):  -5.641678810119629
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.741519
# 3 -0.92280704
# 2 -1.7580818
# 1 -1.7580818
# 0 -1.4883279
# Objective Function J(0):  -6.668817520141602
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.2145771
# 3 -1.5037789
# 2 -0.92529947
# 1 -1.4054189
# 0 -0.76340765
# Objective Function J(0):  -5.812481880187988
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.74188316
# 3 -1.4819158
# 2 -1.3430716
# 1 -0.878571
# 0 -1.3430716
# Objective Function J(0):  -5.78851318359375
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.5337209
# 3 -1.5337209
# 2 -0.84827673
# 1 -0.84827673
# 0 -1.0398449
# Objective Function J(0):  -5.803840160369873
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.3680942
# 3 -1.4315112
# 2 -0.46809164
# 1 -0.89872235
# 0 -1.5022167
# Objective Function J(0):  -5.668636322021484
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.81822324
# 3 -0.6495624
# 2 -1.2490121
# 1 -1.2490121
# 0 -1.3196834
# Objective Function J(0):  -5.28549337387085
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.4708983
# 3 -1.4159476
# 2 -0.8568153
# 1 -0.75051516
# 0 -1.4708983
# Objective Function J(0):  -5.96507453918457
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.641857
# 3 -1.2783626
# 2 -0.641857
# 1 -0.641857
# 0 -0.641857
# Objective Function J(0):  -3.8457908630371094
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.109818295
# 3 -0.8031611
# 2 -1.581437
# 1 -0.8031611
# 0 -0.109818295
# Objective Function J(0):  -3.407395601272583
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.10705913
# 3 -0.10705913
# 2 -0.623307
# 1 -2.5411508
# 0 -0.10705913
# Objective Function J(0):  -3.485635280609131
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.5363062
# 3 -0.17897478
# 2 -1.6657625
# 1 -1.6657625
# 0 -0.5363062
# Objective Function J(0):  -4.5831122398376465
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.597073
# 3 -1.597073
# 2 -1.2819245
# 1 -0.25261965
# 0 -1.597073
# Objective Function J(0):  -6.32576322555542
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.0874759
# 3 -0.7859257
# 2 -1.0874759
# 1 -0.34688511
# 0 -0.7859257
# Objective Function J(0):  -4.093688488006592
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.2537987
# 3 -1.2537987
# 2 -0.6309427
# 1 -2.0220828
# 0 -0.29985464
# Objective Function J(0):  -5.460477828979492
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.47824904
# 3 -0.47824904
# 2 -1.717065
# 1 -0.47824904
# 0 -0.47824904
# Objective Function J(0):  -3.630061149597168
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.3390471
# 3 -1.4633192
# 2 -2.2880833
# 1 -2.2880833
# 0 -0.10562191
# Objective Function J(0):  -7.484154224395752
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: E, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -1.0136298
# 3 -0.65503895
# 2 -1.0531658
# 1 -0.65503895
# 0 -0.65503895
# Objective Function J(0):  -4.031912326812744
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: A action: A, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: C action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: E action: C, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: D action: D, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# 4 -0.8687611
# 3 -0.91838205
# 2 -1.5283415
# 1 -1.5283415
# 0 -0.4308191
# Objective Function J(0):  -5.2746453285217285
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
# Policy - obs: B action: B, yes, right
# Input Tape:  ABCDE
# Output Tape:  ABCDE
# Target Tape:  ABCDE
