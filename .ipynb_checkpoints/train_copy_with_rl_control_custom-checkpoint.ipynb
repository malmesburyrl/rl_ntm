# %%
#IPython magic to reload libraries
# %load_ext autoreload
# %autoreload 2

# Extra code so Juypter doesn't crash on mac os
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import sys
sys.path.insert(0, 'utils')  # noqa

import numpy as np
import gym
import tasks
import ntm
import interfaces

# %%
# Training Params
train_iter = 100
batch_size = 1

# %%
# Task
string_len=5
num_char = 5
env = tasks.Copy(string_len=string_len, max_char=num_char)

# %%
# Controller 
Controller = ntm.NTM(memory_vector_len=10, num_char=num_char, max_run_time=200)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# tape_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# memory_input (InputLayer)       [(None, 10)]         0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 11)           0           tape_input[0][0]
#                                                                  memory_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           384         concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           1056        dense_2[0][0]
# __________________________________________________________________________________________________
# output_content (Dense)          (None, 5)            165         dense_3[0][0]
# __________________________________________________________________________________________________
# output_bool (Dense)             (None, 2)            66          dense_3[0][0]
# __________________________________________________________________________________________________
# input_head_control (Dense)      (None, 3)            99          dense_3[0][0]
# __________________________________________________________________________________________________
# memory_head_control (Dense)     (None, 3)            99          dense_3[0][0]
# __________________________________________________________________________________________________
# memory_content (Dense)          (None, 10)           330         dense_3[0][0]
# ==================================================================================================
# Total params: 2,199
# Trainable params: 2,199
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Over Fit on single char
output = Controller.run(tape_input=1, writes_left=1)
print(output)
Controller.update(output_target=4)

# %%
# Test RL training
output = Controller.run(tape_input=1, writes_left=1)
print(Controller.run_time)
print(Controller.run_time_left(1))
Controller.update_store(1, done=True)

# %%
print(Controller.run_time)
# Out:
# 0

# %%
output_control_cmds = ["no","yes"]
input_control_cmds = ["left","stay","right"]
int_to_char = ["A","B","C","D","E","F","G"]
render_env = False
for i in range(train_iter):
# for i in range(1):

    # Collect experince using current policy/controller
    for j in range(batch_size):
        
        episode_steps = 0
        observation, target, done, info = env.reset()
        if render_env: env.render()

        while True:
            episode_steps += 1
            
            #Run RL-NTM controller and get outputs
            outputs = Controller.run(tape_input=observation, writes_left=info)

            output_content = outputs[0] # Which character to write (ignored if the above sub-action is 0) 
            output_control = outputs[1] #  Whether to write to the output tape ["no","yes"] = [0,1]
            input_control = outputs[2] # Direction to move the read head ["left","right"] = [0,1]
           
            actions = (input_control, output_control, output_content)
            
            if render_env:
                print("Policy - obs: {} action: {}, {}, {}".format(int_to_char[observation],
                      int_to_char[output_content],
                      output_control_cmds[output_control],
                      input_control_cmds[input_control]))

            # target is the expected output for the action that was just taken
            observation, target, done, info = env.step(actions)
            if render_env: env.render()
                
            if output_control_cmds[output_control] == "yes":
                Controller.update_store(output_target=target, done=done)
                
            if done:
                done = False
                break
# Out:
# Input Tape:  DECBE
# Output Tape:
# Target Tape:  DECBE
# Policy - obs: D action: B, yes, right
# Input Tape:  DECBE
# Output Tape:  B
# Target Tape:  DECBE
# Policy - obs: G action: E, yes, stay
# Input Tape:  DECBE
# Output Tape:  BE
# Target Tape:  DECBE
# Policy - obs: D action: E, yes, stay
# Input Tape:  DECBE
# Output Tape:  BEE
# Target Tape:  DECBE
# Policy - obs: E action: E, yes, stay
# Input Tape:  DECBE
# Output Tape:  BEEE
# Target Tape:  DECBE
# Policy - obs: C action: E, yes, stay
# Input Tape:  DECBE
# Output Tape:  BEEEE
# Target Tape:  DECBE
# Input Tape:  DACCC
# Output Tape:
# Target Tape:  DACCC
# Policy - obs: D action: C, no, right
# Input Tape:  DACCC
# Output Tape:
# Target Tape:  DACCC
# Policy - obs: G action: A, no, stay
# Input Tape:  DACCC
# Output Tape:
# Target Tape:  DACCC
# Policy - obs: D action: C, yes, left
# Input Tape:  DACCC
# Output Tape:  C
# Target Tape:  DACCC
# Policy - obs: D action: C, yes, left
# Input Tape:  DACCC
# Output Tape:  CC
# Target Tape:  DACCC
# Policy - obs: D action: C, no, stay
# Input Tape:  DACCC
# Output Tape:  CC
# Target Tape:  DACCC
# Policy - obs: A action: D, yes, stay
# Input Tape:  DACCC
# Output Tape:  CCD
# Target Tape:  DACCC
# Policy - obs: C action: E, yes, left
# Input Tape:  DACCC
# Output Tape:  CCDE
# Target Tape:  DACCC
# Policy - obs: C action: E, yes, right
# Input Tape:  DACCC
# Output Tape:  CCDEE
# Target Tape:  DACCC
# Input Tape:  CDBDA
# Output Tape:
# Target Tape:  CDBDA
# Policy - obs: C action: C, no, right
# Input Tape:  CDBDA
# Output Tape:
# Target Tape:  CDBDA
# Policy - obs: G action: C, yes, left
# Input Tape:  CDBDA
# Output Tape:  C
# Target Tape:  CDBDA
# Policy - obs: G action: E, yes, right
# Input Tape:  CDBDA
# Output Tape:  CE
# Target Tape:  CDBDA
# Policy - obs: G action: E, yes, right
# Input Tape:  CDBDA
# Output Tape:  CEE
# Target Tape:  CDBDA
# Policy - obs: G action: A, yes, right
# Input Tape:  CDBDA
# Output Tape:  CEEA
# Target Tape:  CDBDA
# Policy - obs: G action: E, yes, right
# Input Tape:  CDBDA
# Output Tape:  CEEAE
# Target Tape:  CDBDA
# Input Tape:  CACBB
# Output Tape:
# Target Tape:  CACBB
# Policy - obs: C action: B, yes, left
# Input Tape:  CACBB
# Output Tape:  B
# Target Tape:  CACBB
# Policy - obs: C action: D, yes, left
# Input Tape:  CACBB
# Output Tape:  BD
# Target Tape:  CACBB
# Policy - obs: C action: D, yes, left
# Input Tape:  CACBB
# Output Tape:  BDD
# Target Tape:  CACBB
# Policy - obs: C action: C, yes, left
# Input Tape:  CACBB
# Output Tape:  BDDC
# Target Tape:  CACBB
# Policy - obs: C action: B, yes, left
# Input Tape:  CACBB
# Output Tape:  BDDCB
# Target Tape:  CACBB
# Input Tape:  EEEEC
# Output Tape:
# Target Tape:  EEEEC
# Policy - obs: E action: B, yes, left
# Input Tape:  EEEEC
# Output Tape:  B
# Target Tape:  EEEEC
# Policy - obs: E action: B, yes, left
# Input Tape:  EEEEC
# Output Tape:  BB
# Target Tape:  EEEEC
# Policy - obs: E action: C, yes, left
# Input Tape:  EEEEC
# Output Tape:  BBC
# Target Tape:  EEEEC
# Policy - obs: E action: B, yes, left
# Input Tape:  EEEEC
# Output Tape:  BBCB
# Target Tape:  EEEEC
# Policy - obs: E action: B, yes, left
# Input Tape:  EEEEC
# Output Tape:  BBCBB
# Target Tape:  EEEEC
# Input Tape:  DECAD
# Output Tape:
# Target Tape:  DECAD
# Policy - obs: D action: C, no, left
# Input Tape:  DECAD
# Output Tape:
# Target Tape:  DECAD
# Policy - obs: D action: B, yes, left
# Input Tape:  DECAD
# Output Tape:  B
# Target Tape:  DECAD
# Policy - obs: D action: E, no, stay
# Input Tape:  DECAD
# Output Tape:  B
# Target Tape:  DECAD
# Policy - obs: E action: C, no, stay
# Input Tape:  DECAD
# Output Tape:  B
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  B
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  B
# Target Tape:  DECAD
# Policy - obs: C action: E, no, left
# Input Tape:  DECAD
# Output Tape:  B
# Target Tape:  DECAD
# Policy - obs: C action: C, yes, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: C action: E, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: C action: B, no, right
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: E action: A, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: E action: D, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: E action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: E action: E, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: E action: E, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: E action: E, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: E action: E, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: E action: C, no, stay
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BC
# Target Tape:  DECAD
# Policy - obs: C action: E, yes, left
# Input Tape:  DECAD
# Output Tape:  BCE
# Target Tape:  DECAD
# Policy - obs: C action: E, yes, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: D, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: E, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: E, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: E, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: A, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: B, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: C, no, left
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: C action: D, no, stay
# Input Tape:  DECAD
# Output Tape:  BCEE
# Target Tape:  DECAD
# Policy - obs: A action: E, yes, right
# Input Tape:  DECAD
# Output Tape:  BCEEE
# Target Tape:  DECAD
# Input Tape:  ADCDD
# Output Tape:
# Target Tape:  ADCDD
# Policy - obs: A action: D, yes, left
# Input Tape:  ADCDD
# Output Tape:  D
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  D
# Target Tape:  ADCDD
# Policy - obs: A action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  D
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  D
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  D
# Target Tape:  ADCDD
# Policy - obs: A action: B, yes, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: B, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: B, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DB
# Target Tape:  ADCDD
# Policy - obs: A action: E, yes, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: A action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: A action: C, no, right
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: B, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: B, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: B, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: E, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: D, no, left
# Input Tape:  ADCDD
# Output Tape:  DBE
# Target Tape:  ADCDD
# Policy - obs: G action: C, yes, left
# Input Tape:  ADCDD
# Output Tape:  DBEC
# Target Tape:  ADCDD
# Policy - obs: G action: D, yes, left
# Input Tape:  ADCDD
# Output Tape:  DBECD
# Target Tape:  ADCDD
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, no, left
# Input Tape:  EACBE
# Output Tape:
# Target Tape:  EACBE
# Policy - obs: E action: D, yes, left
# Input Tape:  EACBE
# Output Tape:  D
# Target Tape:  EACBE
# Policy - obs: E action: D, yes, left
# Input Tape:  EACBE
# Output Tape:  DD
# Target Tape:  EACBE
# Policy - obs: E action: D, yes, left
# Input Tape:  EACBE
# Output Tape:  DDD
# Target Tape:  EACBE
# Policy - obs: E action: D, yes, left
# Input Tape:  EACBE
# Output Tape:  DDDD
# Target Tape:  EACBE
# Policy - obs: E action: D, yes, left
# Input Tape:  EACBE
# Output Tape:  DDDDD
# Target Tape:  EACBE
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# ...
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, no, left
# Input Tape:  BBAEB
# Output Tape:
# Target Tape:  BBAEB
# Policy - obs: B action: E, yes, left
# Input Tape:  BBAEB
# Output Tape:  E
# Target Tape:  BBAEB
# Policy - obs: B action: E, yes, left
# Input Tape:  BBAEB
# Output Tape:  EE
# Target Tape:  BBAEB
# Policy - obs: B action: E, yes, left
# Input Tape:  BBAEB
# Output Tape:  EEE
# Target Tape:  BBAEB
# Policy - obs: B action: E, yes, left
# Input Tape:  BBAEB
# Output Tape:  EEEE
# Target Tape:  BBAEB
# Policy - obs: B action: E, yes, left
# Input Tape:  BBAEB
# Output Tape:  EEEEE
# Target Tape:  BBAEB
# Input Tape:  EEBAD
# Output Tape:
# Target Tape:  EEBAD
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-157-21f427af2bdf> in <module>
#      21
#      22             #Run RL-NTM controller and get outputs
# ---> 23             outputs = Controller.run(tape_input=observation, writes_left=info)
#      24
#      25             output_content = outputs[0] # Which character to write (ignored if the above sub-action is 0)
#
# ~/Dropbox/Projects/Deep RL Research/ntm/ntm.py in run(self, tape_input, writes_left)
#     117         with self.Tape as t:
#     118             # print(output_bool)
# --> 119             p_action = output_bool[0, sampled_output_bool] * \
#     120                 input_head_control[0, sampled_input_head_control]
#     121
#
# ~/opt/anaconda3/envs/tf2_robo_research/lib/python3.7/site-packages/tensorflow_core/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     811         ellipsis_mask=ellipsis_mask,
#     812         var=var,
# --> 813         name=name)
#     814
#     815
#
# ~/opt/anaconda3/envs/tf2_robo_research/lib/python3.7/site-packages/tensorflow_core/python/ops/array_ops.py in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#     977       ellipsis_mask=ellipsis_mask,
#     978       new_axis_mask=new_axis_mask,
# --> 979       shrink_axis_mask=shrink_axis_mask)
#     980
#     981   parent_name = name
#
# ~/opt/anaconda3/envs/tf2_robo_research/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_array_ops.py in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10370       else:
#   10371         message = e.message
# > 10372       _six.raise_from(_core._status_to_exception(e.code, message), None)
#   10373   # Add nodes to the TensorFlow graph.
#   10374   if begin_mask is None:
#
# ~/opt/anaconda3/envs/tf2_robo_research/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: slice index 2 of dimension 1 out of bounds. [Op:StridedSlice] name: strided_slice/
